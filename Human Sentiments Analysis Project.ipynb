# %%
import pickle
import pandas as pd
import webbrowser
# !pip install dash
import dash
import dash_html_components as html
import dash_core_components as dcc

import plotly.express as px

from dash.dependencies import Input, Output ,State
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %%
app = dash.Dash()
project_name = None

def load_model():
    global df
    df = pd.read_csv('balanced_reviews.csv')
  
    global pickle_model
    file = open("pickle_model.pkl", 'rb') 
    pickle_model = pickle.load(file)

    global vocab
    file = open("feature.pkl", 'rb') 
    vocab = pickle.load(file)
    
    print(df.sample(5))

def open_browser():
    # Open the default web browser
    webbrowser.open_new('http://127.0.0.1:8050/')
    
def check_review(reviewText):

    transformer = TfidfTransformer()
    loaded_vec = CountVectorizer(decode_error="replace",vocabulary=vocab)
    reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))


    # Add code to test the sentiment of using both the model
    #[0] == negative   [1] == positive
    return pickle_model.predict(reviewText)

# %%
def create_app_ui():
    
    #global dfff
    #dfff = pd.read_csv('ETSY.csv')
    
    
    
    # Create the UI of the Webpage here
    main_layout = html.Div(
    [
    html.H1(children='Sentiments Analysis with Insights',style ={
    "color":"orangered","font-family": "Lucida Console", "Courier New": "monospace",
    "text-align": "center","background-color":"aqua","border-style":" inset","display":"inline-block","width":"100%"
}, id='Main_title'),
            # style={'textAlign': 'center','color':'springgreen'}),
    
    #piechart section
    
    html.H1(children='Pie Chart Section', id='Main_title2',
            style={'textAlign': 'center','color':'orangered'}),
    
    html.Label("Pie Chart of reviews"),
    
    dcc.Dropdown(id='chart',
                options=[
                   {'label':'Chart','value':'overall'}],
                 value='overall',
                 multi=False,
                 clearable=False,
                 style={'width':"50%"}
                 ),
    
    dcc.Graph(id='piechart'),
    
    #review_check section
    
    html.H1(children='Review Check Section', id='Main_title3',
            style={'textAlign': 'center','color':'Blue'}),
    
    
    #dropdown
   
    #dcc.Dropdown(
        #id='drop_down',
        #options = [
           # {'label': i,'value': i}for i in dfff['Reviews_df'].sample(30)
           # ],
        #optionHeight =100,
        #searchable = True,
        #),
    
    html.Button(children='Find The Review', id='button_click', n_clicks=0,
                style={'color':'Tomato'}),
    
    html.H1(children=None, id='result', style={'textAlign': 'center','color':'Violet'}),
    
    #text_review
    
    dcc.Textarea(
        id='textarea_review',
        placeholder='Enter the review here...',
        style={'width': '100%', 'height': 100, 'background':'springgreen'},
        ),
    
    html.Button(children='Find Review of the entered data', id='button_click1', n_clicks=0,
                style={'color':'Tomato'}),
    
    html.H1(children=None, id='result1', style={'textAlign': 'center','color':'mediumturquoise'}),
    
    
    
    ]
    )
    
    return main_layout

# %%
@app.callback(
    Output("piechart", "figure"), 
    [Input("chart", "value")
     ])
def generate_chart(chart):
    dff=df
    
    fig = px.pie(
        data_frame=dff,
        names=chart)
    return fig


#text_area

@app.callback(
    Output('result1', 'children'),
    [
    Input('button_click1', 'n_clicks')
    ],
    [
    State('textarea_review', 'value') 
    ]
    )
def update_app_ui(n_clicks,textarea_value):
    
    print("Data Type  = ", str(type(textarea_value)))
    print("Value      = ", str(textarea_value))

    
    result_list = check_review(textarea_value)
    
    if (result_list[0] == 0 ):
        result = 'Negative'
    elif (result_list[0] == 1 ):
        result = 'Positive'
    else:
        result = 'Unknown'
    
    return result

#for_drop_down

@app.callback(
    Output('result', 'children'),
    [
    Input('button_click', 'n_clicks'), 
    ],
    [
    State('drop_down', 'value') ,
    ]
    )
def update_app_ui_drop(n_clicks,drop_down):
    
    print("Data Type  = ", str(type(drop_down)))
    print("Value      = ", str(drop_down))

    
    result_list = check_review(drop_down)
    
    if (result_list[0] == 0 ):
        result = 'Negative'
    elif (result_list[0] == 1 ):
        result = 'Positive'
    else:
        result = 'Unknown'
    
    return result

# %%
def main():
    load_model()    
    open_browser()
    

    global project_name
    project_name = "Sentiments Analysis with Insights" 
      
    global app
    app.layout = create_app_ui()
    app.title = project_name
    
    app.run_server() # debug=True
  
    print("This would be executed only after the script is closed")
    app = None
    project_name = None

if __name__ == '__main__':
    main()
# Out:
#         overall                                         reviewText  \
# 538177        3                         not good for kitchen work.
# 431568        1       Nothing like the picture. Low quality smh...
# 185008        2                       Watch was too big for my arm
# 444977        3  These are not very comfortable for me. I think...
# 602187        5                                            love it
#
#                                       summary
# 538177                     Dont work in these
# 431568                           not worth it
# 185008                                Too Big
# 444977  These are not very comfortable for me
# 602187                             Five Stars
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
# INFO:__main__:Dash is running on http://127.0.0.1:8050/
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# INFO:werkzeug: * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [24/Jan/2021 19:17:33] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Jan/2021 19:17:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jan/2021 19:17:35] "GET /_dash-dependencies HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Jan/2021 19:17:35] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jan/2021 19:17:35] "GET /_dash-layout HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Jan/2021 19:17:35] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jan/2021 19:17:35] "GET /_favicon.ico?v=1.18.1 HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Jan/2021 19:17:35] "GET /_favicon.ico?v=1.18.1 HTTP/1.1" 200 -
# Data Type  =  <class 'NoneType'>
# Value      =  None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
# ...
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# ERROR:__main__:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "F:\Python Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "F:\Python Anaconda\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "F:\Python Anaconda\lib\site-packages\dash\dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-195-3b118795f2d4>", line 31, in update_app_ui
#     result_list = check_review(textarea_value)
#   File "<ipython-input-193-2a74a210f906>", line 26, in check_review
#     reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1198, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents,
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 1110, in _count_vocab
#     for feature in analyze(doc):
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 104, in _analyze
#     doc = preprocessor(doc)
#   File "F:\Python Anaconda\lib\site-packages\sklearn\feature_extraction\text.py", line 69, in _preprocess
#     doc = doc.lower()
# AttributeError: 'NoneType' object has no attribute 'lower'
# 127.0.0.1 - - [24/Jan/2021 19:17:38] "POST /_dash-update-component HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [24/Jan/2021 19:17:38] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [24/Jan/2021 19:17:40] "POST /_dash-update-component HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Jan/2021 19:17:40] "POST /_dash-update-component HTTP/1.1" 200 -
